# %% [markdown]
# ## Importing packages and importing data

# %%
import pandas as pd
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
Data_Indo_Jkt = pd.read_excel('Daily Update Data Agregat Covid-19 Jakarta.xlsx',sheet_name=0)
Data_Jkt = pd.read_excel('Daily Update Data Agregat Covid-19 Jakarta.xlsx',sheet_name=1)
Data_Suspek_Jkt = pd.read_excel('Daily Update Data Agregat Covid-19 Jakarta.xlsx',sheet_name=2)
Data_RDT_Ab = pd.read_excel('Daily Update Data Agregat Covid-19 Jakarta.xlsx',sheet_name=3)
Data_RDT_Ag = pd.read_excel('Daily Update Data Agregat Covid-19 Jakarta.xlsx',sheet_name=4)
Data_Hasil_Lab = pd.read_excel('Daily Update Data Agregat Covid-19 Jakarta.xlsx',sheet_name=5)
Data_Vaksinasi= pd.read_excel('Daily Update Data Agregat Covid-19 Jakarta.xlsx',sheet_name=6)
Data_Pemakaman = pd.read_excel('Daily Update Data Agregat Covid-19 Jakarta.xlsx',sheet_name=7)
Data_Vaksinasi_Wilayah = pd.read_excel('Daily Update Data Agregat Covid-19 Jakarta.xlsx',sheet_name=8)
Data_Daily_Vaksinasi_Wilayah = pd.read_excel('Daily Update Data Agregat Covid-19 Jakarta.xlsx',sheet_name=9)

# %% [markdown]
# ### Data Checking

# %% [markdown]
# **1. Data Indo Jakarta**

# %%
Data_Indo_Jkt.drop(columns=['Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
       'Unnamed: 25', 'Unnamed: 26'],inplace=True)
Data_Indo_Jkt.head()
# Out:
#      Tanggal  Meninggal (Indonesia)  Sembuh (Indonesia)  Dirawat (Indonesia)  \
# 0 2020-03-01                      0                   0                    0
# 1 2020-03-02                      0                   0                    2
# 2 2020-03-03                      0                   0                    2
# 3 2020-03-04                      0                   0                    2
# 4 2020-03-05                      0                   0                    2
#
#    Positif (Indonesia)  Meninggal (Jakarta)  Sembuh (Jakarta)  \
# 0                    0                    0                 0
# 1                    2                    0                 0
# 2                    2                    1                 0
# 3                    2                    1                 0
# 4                    2                    3                 0
#
#    Self-Isolation (Jakarta)  Dirawat (Jakarta)  Positif (Jakarta)  \
# ...

# %% [markdown]
# **2. Data Jakarta**

# %%
Data_Jkt.drop(columns=['Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19','Unnamed: 20','Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
       'Unnamed: 25', 'Unnamed: 26','Unnamed: 27', 'Unnamed: 28'],inplace=True)
Data_Jkt.head()
# Out:
#      Tanggal  Jam         Tanggal Jam  Total Pasien  Sembuh  Meninggal  \
# 0 2020-03-01  NaN 2020-03-01 18:00:00             0       0          0
# 1 2020-03-02  NaN 2020-03-02 18:00:00             0       0          0
# 2 2020-03-03  NaN 2020-03-03 18:00:00             3       0          1
# 3 2020-03-04  NaN 2020-03-04 18:00:00             3       0          1
# 4 2020-03-05  NaN 2020-03-05 18:00:00             7       0          3
#
#    Self Isolation  Masih Perawatan  Belum Diketahui (masih verifikasi)  \
# 0               0                0                                 NaN
# 1               0                0                                 NaN
# 2               0                2                                 NaN
# 3               0                2                                 NaN
# 4               0                4                                 NaN
#
#    Menunggu Hasil  Tenaga Kesehatan Terinfeksi  Positif Harian  Positif Aktif  \
# ...

# %% [markdown]
# **3.Data Suspek Jakarta**

# %%
Data_Suspek_Jkt.head()
# Out:
#      Tanggal  Total Discarded  Isolasi di RS (Discarded)  \
# 0 2020-07-17             5712                        NaN
# 1 2020-07-18             5713                        NaN
# 2 2020-07-19             5713                        NaN
# 3 2020-07-20             5713                        NaN
# 4 2020-07-21             5643                        NaN
#
#    Isolasi di Rumah (Discarded)  Meninggal (Discarded)  \
# 0                           NaN                    NaN
# 1                           NaN                    NaN
# 2                           NaN                    NaN
# 3                           NaN                    NaN
# 4                           NaN                    NaN
#
#    Selesai Isolasi (Discarded)  Total Kontak Erat  \
# 0                         5712              78725
# 1                         5713              80382
# 2                         5713              81327
# 3                         5713              81739
# ...

# %% [markdown]
# **4.Data Rapid Test Antibodi**

# %%
Data_RDT_Ab.head()
# Out:
#    No.    Tanggal  Reaktif  Non-Reaktif  Total  Positivity Rate  Unnamed: 6  \
# 0    1 2020-03-27      124        10839  10963         0.011311         NaN
# 1    2 2020-03-28      149        11858  12007         0.012409         NaN
# 2    3 2020-03-29      206        14808  15014         0.013721         NaN
# 3    4 2020-03-30      290        17619  17909         0.016193         NaN
# 4    5 2020-03-31      307        18242  18549         0.016551         NaN
#
#                                             catatan:  Unnamed: 8  Unnamed: 9  \
# 0  kolom "Tanggal" = tanggal 1 hari sebelum updat...         NaN         NaN
# 1                                                NaN         NaN         NaN
# 2                                                NaN         NaN         NaN
# 3                                                NaN         NaN         NaN
# 4                                                NaN         NaN         NaN
#
# ...

# %%
Data_RDT_Ab = Data_RDT_Ab[['No.', 'Tanggal', 'Reaktif', 'Non-Reaktif', 'Total', 'Positivity Rate']]

# %%
Data_RDT_Ab.head()
# Out:
#    No.    Tanggal  Reaktif  Non-Reaktif  Total  Positivity Rate
# 0    1 2020-03-27      124        10839  10963         0.011311
# 1    2 2020-03-28      149        11858  12007         0.012409
# 2    3 2020-03-29      206        14808  15014         0.013721
# 3    4 2020-03-30      290        17619  17909         0.016193
# 4    5 2020-03-31      307        18242  18549         0.016551

# %% [markdown]
# **5. Data Rapid Test Antigen**

# %%
Data_RDT_Ag.columns = ['No','Tgl','Positif_EIS','Negatif_EIS','Total_EIS','Positivity Rate_EIS','Positif_NAR','Negatif_NAR','Total_NAR','Positivity Rate_NAR','Positif_Excel','Negatif_Excel','Total_Excel','Positivity Rate_Excel','Tes Harian_DKI_JKT','Positif Harian_DKI_JKT','Negatif Harian_DKI_JKT','Positivity Rate Harian_DKI_JKT','Total Kumulatif_DKI_JKT','Positif Kumulatif_DKI_JKT','Negatif Kumulatif_DKI_JKT','Positivity Rate Kumulatif_DKI_JKT']

# %%
Data_RDT_Ag = Data_RDT_Ag.iloc[1: , :]

# %%
Data_RDT_Ag.head()
# Out:
#     No                  Tgl Positif_EIS Negatif_EIS Total_EIS  \
# 1  1.0  2021-01-01 00:00:00          76        1116      1192
# 2  2.0  2021-01-02 00:00:00          76        1116      1192
# 3  3.0  2021-01-03 00:00:00         100        1699      1799
# 4  4.0  2021-01-04 00:00:00         100        1699      1799
# 5  5.0  2021-01-05 00:00:00         100        1699      1799
#
#   Positivity Rate_EIS Positif_NAR Negatif_NAR Total_NAR Positivity Rate_NAR  \
# 1            0.063758           0           0         0             #DIV/0!
# 2            0.063758           0           0         0             #DIV/0!
# 3            0.055586           0           0         0             #DIV/0!
# 4            0.055586           0           0         0             #DIV/0!
# 5            0.055586           0           0         0             #DIV/0!
#
#   Positif_Excel Negatif_Excel Total_Excel Positivity Rate_Excel  \
# 1             0             0           0               #DIV/0!
# ...

# %% [markdown]
# **6. Hasil Lab**

# %%
Data_Hasil_Lab = Data_Hasil_Lab[['Tanggal', 'Jumlah Orang di Test', 'Orang Positif Harian',
       'Orang Negatif Harian', 'Positivity Rate Kasus Baru Harian',
       'Total Spesimen di Test', 'Positif', 'Negatif',
       'Positivity Rate Spesimen Harian']]

# %%
Data_Hasil_Lab.head()
# Out:
#      Tanggal  Jumlah Orang di Test  Orang Positif Harian  \
# 0 2020-02-29                    40                     0
# 1 2020-03-01                    39                     0
# 2 2020-03-02                     3                     0
# 3 2020-03-03                    15                     3
# 4 2020-03-04                     7                     0
#
#    Orang Negatif Harian  Positivity Rate Kasus Baru Harian  \
# 0                    40                                0.0
# 1                    39                                0.0
# 2                     3                                0.0
# 3                    12                                0.2
# 4                     7                                0.0
#
#    Total Spesimen di Test  Positif  Negatif Positivity Rate Spesimen Harian
# 0                      40        0       40                            0,0%
# 1                      39        0       39                            0,0%
# ...

# %% [markdown]
# **7. Data Vaksinasi**

# %% [markdown]
# _Keep it as a note:_
#
# * Sasaran Total Indonesia: `181.554.465`
# * Sasaran Total DKI Jakarta: `8.815.157`

# %%
Data_Vaksinasi.columns = Data_Vaksinasi.iloc[3]
Data_Vaksinasi = Data_Vaksinasi.iloc[4: , :]
Data_Vaksinasi.head()
# Out:
# 3                  NaN Target Vaksinasi Vaksinasi 1 Vaksinasi 2 Persentase 1  \
# 4  2021-03-05 00:00:00           112301      141425       91078     1.259339
# 5  2021-03-06 00:00:00           112301      144046       91379     1.282678
# 6  2021-03-07 00:00:00           112301      177126       91460     1.577243
# 7  2021-03-08 00:00:00           112301      181237       92988      1.61385
# 8  2021-03-09 00:00:00           112301      113326       89984     1.009127
#
# 3 Persentase 2 Target Vaksinasi Vaksinasi 1 Vaksinasi 2 Persentase 1  \
# 4     0.811017           911631       76451           0     0.083862
# 5     0.813697           911631       79421           0      0.08712
# 6     0.814418           911631       83628           0     0.091734
# 7     0.828025           911631       95140           1     0.104362
# 8     0.801275           911631      135128         675     0.148227
#
# 3 Persentase 2 Target Vaksinasi Vaksinasi 1 Vaksinasi 2 Persentase 1  \
# ...

# %%
# ['Target Vaksinasi','Vaksinasi 1','Vaksinasi 2','Persentase 1','Persentase 2']
Data_Vaksinasi.columns = ['Tanggal','Target Vaksinasi_TenagaKesehatanDKI','Vaksinasi 1_TenagaKesehatanDKI','Vaksinasi 2_TenagaKesehatanDKI','Persentase 1_TenagaKesehatanDKI','Persentase 2_TenagaKesehatanDKI',
                          'Target Vaksinasi_LansiaDKI','Vaksinasi 1_LansiaDKI','Vaksinasi 2_LansiaDKI','Persentase 1_LansiaDKI','Persentase 2_LansiaDKI',
                         'Target Vaksinasi_PelayananPublikDKI','Vaksinasi 1_PelayananPublikDKI','Vaksinasi 2_PelayananPublikDKI','Persentase 1_PelayananPublikDKI','Persentase 2_PelayananPublikDKI',
                         'Target Vaksinasi_TotalDKIjkt','Vaksinasi 1_TotalDKIjkt','Vaksinasi 2_TotalDKIjkt','Persentase 1_TotalDKIjkt','Persentase 2_TotalDKIjkt',
                         'Vaksinasi 1_HarianDKI','Vaksinasi 2_HarianDKI',
                         'Target Vaksinasi_18-59 tahunDKI','Vaksinasi 1_18-59 tahunDKI','Vaksinasi 2_18-59 tahunDKI','Persentase 1_18-59 tahunDKI','Persentase 2_18-59 tahunDKI',
                         'Target Vaksinasi_12-17 tahunDKI','Vaksinasi 1_12-17 tahunDKI','Vaksinasi 2_12-17 tahunDKI','Persentase 1_12-17 tahunDKI','Persentase 2_12-17 tahunDKI',
                         'Target Vaksinasi_TenagaKesehatanIndo','Vaksinasi 1_TenagaKesehatanIndo','Vaksinasi 2_TenagaKesehatanIndo','Persentase 1_TenagaKesehatanIndo','Persentase 2_TenagaKesehatanIndo',
                          'Target Vaksinasi_LansiaIndo','Vaksinasi 1_LansiaIndo','Vaksinasi 2_LansiaIndo','Persentase 1_LansiaIndo','Persentase 2_LansiaIndo',
                         'Target Vaksinasi_PelayananPublikIndo','Vaksinasi 1_PelayananPublikIndo','Vaksinasi 2_PelayananPublikIndo','Persentase 1_PelayananPublikIndo','Persentase 2_PelayananPublikIndo',
                         'Target Vaksinasi_TotalIndo','Vaksinasi 1_TotalIndo','Vaksinasi 2_TotalIndo','Persentase 1_TotalIndo','Persentase 2_TotalIndo',
                         'Vaksinasi 1_HarianIndo','Vaksinasi 2_HarianIndo',
                         'Target Vaksinasi_18-59 tahunIndo','Vaksinasi 1_18-59 tahunIndo','Vaksinasi 2_18-59 tahunIndo','Persentase 1_18-59 tahunIndo','Persentase 2_18-59 tahunIndo',
                         'Target Vaksinasi_12-17 tahunIndo','Vaksinasi 1_12-17 tahunIndo','Vaksinasi 2_12-17 tahunIndo','Persentase 1_12-17 tahunIndo','Persentase 2_12-17 tahunIndo',
                         'Proposi Vaksin Jakarta D1','Proposi Vaksin Jakarta D2',
                         'Vaksin Gtg Ryg 1_DKI','Vaksin Gtg Ryg 2_DKI','Vaksin Gtg Ryg 1_Indo','Vaksin Gtg Ryg 2_Indo']

# %%
Data_Vaksinasi.head()
# Out:
#                Tanggal Target Vaksinasi_TenagaKesehatanDKI  \
# 4  2021-03-05 00:00:00                              112301
# 5  2021-03-06 00:00:00                              112301
# 6  2021-03-07 00:00:00                              112301
# 7  2021-03-08 00:00:00                              112301
# 8  2021-03-09 00:00:00                              112301
#
#   Vaksinasi 1_TenagaKesehatanDKI Vaksinasi 2_TenagaKesehatanDKI  \
# 4                         141425                          91078
# 5                         144046                          91379
# 6                         177126                          91460
# 7                         181237                          92988
# 8                         113326                          89984
#
#   Persentase 1_TenagaKesehatanDKI Persentase 2_TenagaKesehatanDKI  \
# 4                        1.259339                        0.811017
# 5                        1.282678                        0.813697
# ...

# %% [markdown]
# **8. Data Pemakaman**

# %%
Data_Pemakaman = Data_Pemakaman[['Tanggal', 'Pemakaman_COVID19_Harian', 'Total_Pemakaman_COVID19',
       'Pemakaman_Umum_Harian', 'Total_Pemakaman_Umum']]

# %%
Data_Pemakaman.columns
# Out:
# Index(['Tanggal', 'Pemakaman_COVID19_Harian', 'Total_Pemakaman_COVID19',
#        'Pemakaman_Umum_Harian', 'Total_Pemakaman_Umum'],
#       dtype='object')

# %%
Data_Pemakaman.head()
# Out:
#      Tanggal  Pemakaman_COVID19_Harian  Total_Pemakaman_COVID19  \
# 0 2020-03-01                         0                        0
# 1 2020-03-02                         0                        0
# 2 2020-03-03                         0                        0
# 3 2020-03-04                         0                        0
# 4 2020-03-05                         0                        0
#
#    Pemakaman_Umum_Harian  Total_Pemakaman_Umum
# 0                    150                   150
# 1                    136                   286
# 2                    135                   421
# 3                    116                   537
# 4                    124                   661

# %% [markdown]
# **9. Vaksinasi Wilayah**

# %%
Data_Vaksinasi_Wilayah = pd.read_excel('Daily Update Data Agregat Covid-19 Jakarta.xlsx',sheet_name=8)

# %%
Data_Vaksinasi_Wilayah.head()
# Out:
#    No.   Kecamatan  Kota / Kabupaten  Target Total per Kecamatan  \
# 0  No.   Kecamatan  Kota / Kabupaten  Target Total per Kecamatan
# 1    1      Cakung     Jakarta Timur                      393257
# 2    2  Cengkareng     Jakarta Barat                      400577
# 3    3  Kali Deres     Jakarta Barat                      310580
# 4    4   Cilincing     Jakarta Utara                      297146
#
#    Target Harian per Kecamatan Cakupan 13 Jan - 11 Juni      Unnamed: 6  \
# 0  Target Harian per Kecamatan         Cakupan Suntik 1      Keterangan
# 1                         5333                    74966  Tidak Tercapai
# 2                         5041                    85668  Tidak Tercapai
# 3                         4295                    42991  Tidak Tercapai
# 4                         4073                    41494  Tidak Tercapai
#
#          Unnamed: 7   Cakupan 12 Juni      Unnamed: 9       Unnamed: 10  \
# ...

# %%
Data_Vaksinasi_Wilayah.columns = Data_Vaksinasi_Wilayah.iloc[0]

# %%
Data_Vaksinasi_Wilayah = Data_Vaksinasi_Wilayah.iloc[1: , :]

# %%
Data_Vaksinasi_Wilayah.head()
# Out:
# 0 No.    Kecamatan Kota / Kabupaten Target Total per Kecamatan  \
# 1   1       Cakung    Jakarta Timur                     393257
# 2   2   Cengkareng    Jakarta Barat                     400577
# 3   3   Kali Deres    Jakarta Barat                     310580
# 4   4    Cilincing    Jakarta Utara                     297146
# 5   5  Duren Sawit    Jakarta Timur                     316352
#
# 0 Target Harian per Kecamatan Cakupan Suntik 1      Keterangan  \
# 1                        5333            74966  Tidak Tercapai
# 2                        5041            85668  Tidak Tercapai
# 3                        4295            42991  Tidak Tercapai
# 4                        4073            41494  Tidak Tercapai
# 5                        4006            41413  Tidak Tercapai
#
# 0 Cakupan Suntik 2 Cakupan Suntik 1      Keterangan Cakupan Suntik 2  \
# 1            37590              897  Tidak Tercapai                0
# ...

# %%
Data_Vaksinasi_Wilayah = Data_Vaksinasi_Wilayah.iloc[: , :-5]

# %%
Data_Vaksinasi_Wilayah.head()
# Out:
# 0 No.    Kecamatan Kota / Kabupaten Target Total per Kecamatan  \
# 1   1       Cakung    Jakarta Timur                     393257
# 2   2   Cengkareng    Jakarta Barat                     400577
# 3   3   Kali Deres    Jakarta Barat                     310580
# 4   4    Cilincing    Jakarta Utara                     297146
# 5   5  Duren Sawit    Jakarta Timur                     316352
#
# 0 Target Harian per Kecamatan Cakupan Suntik 1      Keterangan  \
# 1                        5333            74966  Tidak Tercapai
# 2                        5041            85668  Tidak Tercapai
# 3                        4295            42991  Tidak Tercapai
# 4                        4073            41494  Tidak Tercapai
# 5                        4006            41413  Tidak Tercapai
#
# 0 Cakupan Suntik 2 Cakupan Suntik 1      Keterangan Cakupan Suntik 2  \
# 1            37590              897  Tidak Tercapai                0
# ...

# %%
Data_Vaksinasi_Wilayah.columns = [   'No.', 'Kecamatan','Kota / Kabupaten',  
                                  'Target Total per Kecamatan',
       'Target Harian per Kecamatan',            'Cakupan Suntik 1_13 Jan-11 Jun',
                        'Keterangan_13 Jan-11 Jun',            'Cakupan Suntik 2_13 Jan-11 Jun',
                  'Cakupan Suntik 1_12 Juni',                  'Keterangan_12 Juni',
                  'Cakupan Suntik 2_12 Juni',            'Cakupan Suntik 1_13 Juni',
                        'Keterangan_13 Juni',            'Cakupan Suntik 2_13 Juni',
                  'Cakupan Suntik 1_14 Juni',                  'Keterangan_14 Juni',
                  'Cakupan Suntik 2_14 Juni',            'Cakupan Suntik 1_15 Juni',
                        'Keterangan_15 Juni',            'Cakupan Suntik 2_15 Juni',
                  'Cakupan Suntik 1_16 Juni',                  'Keterangan_16 Juni',
                  'Cakupan Suntik 2_16 Juni',            'Cakupan Suntik 1_17 Juni',
                        'Keterangan_17 Juni',            'Cakupan Suntik 2_17 Juni',
                  'Cakupan Suntik 1_18 Juni',                  'Keterangan_18 Juni',
                  'Cakupan Suntik 2_18 Juni',            'Cakupan Suntik 1_19 Juni',
                        'Keterangan_19 Juni',            'Cakupan Suntik 2_19 Juni',
                  'Cakupan Suntik 1_20 Juni',                  'Keterangan_20 Juni',
                  'Cakupan Suntik 2_20 Juni',            'Cakupan Suntik 1_21 Juni',
                        'Keterangan_21 Juni',            'Cakupan Suntik 2_21 Juni',
                  'Cakupan Suntik 1_22 Juni',                  'Keterangan_22 Juni',
                  'Cakupan Suntik 2_22 Juni',            'Cakupan Suntik 1_23 Juni',
                        'Keterangan_23 Juni',            'Cakupan Suntik 2_23 Juni',
                  'Cakupan Suntik 1_24 Juni',                  'Keterangan_24 Juni',
                  'Cakupan Suntik 2_24 Juni',            'Cakupan Suntik 1_25 Juni',
                        'Keterangan_25 Juni',            'Cakupan Suntik 2_25 Juni',
                  'Cakupan Suntik 1_26 Juni',                  'Keterangan_26 Juni',
                  'Cakupan Suntik 2_26 Juni',            'Cakupan Suntik 1_27 Juni',
                        'Keterangan_27 Juni',            'Cakupan Suntik 2_27 Juni',
                  'Cakupan Suntik 1_28 Juni',                  'Keterangan_28 Juni',
                  'Cakupan Suntik 2_28 Juni',            'Cakupan Suntik 1_29 Juni',
                        'Keterangan_29 Juni',            'Cakupan Suntik 2_29 Juni',
                  'Cakupan Suntik 1_30 Juni',                  'Keterangan_30 Juni',
                  'Cakupan Suntik 2_30 Juni',            'Cakupan Suntik 1_1 Juli',
                        'Keterangan_1 Juli',            'Cakupan Suntik 2_1 Juli',
                  'Cakupan Suntik 1_2 Juli',                  'Keterangan_2 Juli',
                  'Cakupan Suntik 2_2 Juli',            'Cakupan Suntik 1_3 Juli',
                        'Keterangan_3 Juli',            'Cakupan Suntik 2_3 Juli',
                  'Cakupan Suntik 1_4 Juli',                  'Keterangan_4 Juli',
                  'Cakupan Suntik 2_4 Juli',            'Cakupan Suntik 1_5 Juli',
                        'Keterangan_5 Juli',            'Cakupan Suntik 2_5 Juli',
                  'Cakupan Suntik 1_6 Juli',                  'Keterangan_6 Juli',
                  'Cakupan Suntik 2_6 Juli']

# %%
Data_Vaksinasi_Wilayah.head()
# Out:
#   No.    Kecamatan Kota / Kabupaten Target Total per Kecamatan  \
# 1   1       Cakung    Jakarta Timur                     393257
# 2   2   Cengkareng    Jakarta Barat                     400577
# 3   3   Kali Deres    Jakarta Barat                     310580
# 4   4    Cilincing    Jakarta Utara                     297146
# 5   5  Duren Sawit    Jakarta Timur                     316352
#
#   Target Harian per Kecamatan Cakupan Suntik 1_13 Jan-11 Jun  \
# 1                        5333                          74966
# 2                        5041                          85668
# 3                        4295                          42991
# 4                        4073                          41494
# 5                        4006                          41413
#
#   Keterangan_13 Jan-11 Jun Cakupan Suntik 2_13 Jan-11 Jun  \
# 1           Tidak Tercapai                          37590
# 2           Tidak Tercapai                          47581
# ...

# %% [markdown]
# **10. Data Daily Vaksinasi Wilayah**

# %%
Data_Daily_Vaksinasi_Wilayah = Data_Daily_Vaksinasi_Wilayah.iloc[:,:4]
Data_Daily_Vaksinasi_Wilayah.head()
# Out:
#      Tanggal  Cakupan Suntik 1  Cakupan Suntik 2  Unnamed: 3
# 0 2021-06-11           2819926         1852994.0           1
# 1 2021-06-12             19281            1173.0           4
# 2 2021-06-13               198              29.0           7
# 3 2021-06-14             79491            3691.0          10
# 4 2021-06-15             81545            3385.0          13

# %%
print('\n')

# %% [markdown]
# ## 1) Temukan nilai mean, median, dan modus dari positif COVID-19 harian Jakarta

# %%
Data_Jkt['Jam'] = [d.time() for d in Data_Jkt['Tanggal Jam']]
Data_Jkt.head()
# Out:
#      Tanggal       Jam         Tanggal Jam  Total Pasien  Sembuh  Meninggal  \
# 0 2020-03-01  18:00:00 2020-03-01 18:00:00             0       0          0
# 1 2020-03-02  18:00:00 2020-03-02 18:00:00             0       0          0
# 2 2020-03-03  18:00:00 2020-03-03 18:00:00             3       0          1
# 3 2020-03-04  18:00:00 2020-03-04 18:00:00             3       0          1
# 4 2020-03-05  18:00:00 2020-03-05 18:00:00             7       0          3
#
#    Self Isolation  Masih Perawatan  Belum Diketahui (masih verifikasi)  \
# 0               0                0                                 NaN
# 1               0                0                                 NaN
# 2               0                2                                 NaN
# 3               0                2                                 NaN
# 4               0                4                                 NaN
#
#    Menunggu Hasil  Tenaga Kesehatan Terinfeksi  Positif Harian  Positif Aktif  \
# ...

# %%
print('Rata-Rata Kasus Positif Covid-19 Harian Jakarta:',Data_Jkt['Positif Harian'].mean())
print('Median dari Kasus Positif Covid-19 Harian Jakarta:',Data_Jkt['Positif Harian'].median())
print('Modus dari Kasus Positif Covid-19 Harian Jakarta:',Data_Jkt['Positif Harian'].mode()[0],'sebanyak {} kali'.format(Data_Jkt['Positif Harian'].value_counts().sort_values(ascending=False)[0]))
# Out:
# Rata-Rata Kasus Positif Covid-19 Harian Jakarta: 1218.9391480730224
# Median dari Kasus Positif Covid-19 Harian Jakarta: 862.0
# Modus dari Kasus Positif Covid-19 Harian Jakarta: 0 sebanyak 7 kali

# %% [markdown]
# ## 2) Dari dataset yang disediakan, temukan nilai minimal dan maksimal dari positif COVID-19 harian Jakarta.

# %%
print('Nilai Minimal Dari Kasus Positif Covid-19 Harian Jakarta adalah sebanyak {} kasus'.format(Data_Jkt['Positif Harian'].min()))
print('Dan Nilai Maksimal Dari Kasus Positif Covid-19 Harian Jakarta adalah sebanyak {} kasus'.format(Data_Jkt['Positif Harian'].max()))
# Out:
# Nilai Minimal Dari Kasus Positif Covid-19 Harian Jakarta adalah sebanyak 0 kasus
# Dan Nilai Maksimal Dari Kasus Positif Covid-19 Harian Jakarta adalah sebanyak 10903 kasus

# %% [markdown]
# ## 3) Dari dataset yang disediakan, temukan nilai-nilai outlier yang ada (menggunakan variabel yang kalian tentukan).

# %%
for i in Data_Indo_Jkt.columns:  
    Q1  = Data_Indo_Jkt[i].quantile(0.25)
    Q3  = Data_Indo_Jkt[i].quantile(0.75)
    IQR = Q3-Q1

    Lower_Bound = Q1-(1.5*IQR)
    Upper_Bound = Q3+(1.5*IQR)

    print('Kolom',i,'Memiliki Outliers sebesar:',len(Data_Indo_Jkt[(Data_Indo_Jkt[i]>Upper_Bound)|(Data_Indo_Jkt[i]<Lower_Bound)])/len(Data_Indo_Jkt)*100,'%')
print('\n')
# Out:
# Kolom Tanggal Memiliki Outliers sebesar: 0.0 %
# Kolom Meninggal (Indonesia) Memiliki Outliers sebesar: 0.0 %
# Kolom Sembuh (Indonesia) Memiliki Outliers sebesar: 0.0 %
# Kolom Dirawat (Indonesia) Memiliki Outliers sebesar: 1.4198782961460445 %
# Kolom Positif (Indonesia) Memiliki Outliers sebesar: 0.0 %
# Kolom Meninggal (Jakarta) Memiliki Outliers sebesar: 0.0 %
# Kolom Sembuh (Jakarta) Memiliki Outliers sebesar: 0.0 %
# Kolom Self-Isolation (Jakarta) Memiliki Outliers sebesar: 7.505070993914807 %
# Kolom Dirawat (Jakarta) Memiliki Outliers sebesar: 5.476673427991886 %
# Kolom Positif (Jakarta) Memiliki Outliers sebesar: 0.0 %
# Kolom Positif Aktif (Jakarta) Memiliki Outliers sebesar: 4.259634888438134 %
# Kolom Meninggal Harian (Indonesia) Memiliki Outliers sebesar: 3.2454361054766734 %
# Kolom Sembuh Harian (Indonesia) Memiliki Outliers sebesar: 0.4056795131845842 %
# Kolom Dirawat Harian (Indonesia) Memiliki Outliers sebesar: 16.227180527383368 %
# ...

# %% [markdown]
# Akan kita coba ekstrak Outliers dari kolom **Positif Aktif Harian (Jakarta)**, karena kolom ini yang memiliki outliers paling banyak di dalam dataset ini.

# %%
for i in ['Positif Aktif Harian (Jakarta)']:  
    Q1  = Data_Indo_Jkt[i].quantile(0.25)
    Q3  = Data_Indo_Jkt[i].quantile(0.75)
    IQR = Q3-Q1

    Lower_Bound = Q1-(1.5*IQR)
    Upper_Bound = Q3+(1.5*IQR)

#     print('Kolom',i,'Memiliki Outliers sebesar:',len(Data_Indo_Jkt[(Data_Indo_Jkt[i]>Upper_Bound)|(Data_Indo_Jkt[i]<Lower_Bound)])/len(Data_Indo_Jkt)*100,'%')
Outliers_Positif_Aktif_Jkt = Data_Indo_Jkt[(Data_Indo_Jkt[i]>Upper_Bound)|(Data_Indo_Jkt[i]<Lower_Bound)]
print(Outliers_Positif_Aktif_Jkt['Positif Aktif Harian (Jakarta)'].mean())
print(Data_Indo_Jkt['Positif Aktif Harian (Jakarta)'].mean())
# Out:
# 838.5833333333334
# 191.85395537525355
